# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
x= [63,56,78,50,91]
plt.pie(x, labels = ["ramesh","gopal","mohan","shyam","mantu"], colors=['red','green','pink','yellow','black'], radius = 1,startangle = 90, counterclock = True)
# plt.legend()
plt.show()

# %%
df = pd.read_csv('practice2.csv')
df
# Out:
#    years  sell_of_mi
# 0   2016       140.0
# 1   2017       125.0
# 2   2018         NaN
# 3   2019       135.0
# 4   2020       140.0
# 5   2021       145.0
# 6   2022       160.0
# 7   2023       155.0
# 8   2024       170.0

# %%
df.fillna(180, inplace=True)
df
# Out:
#    years  sell_of_mi
# 0   2016       140.0
# 1   2017       125.0
# 2   2018       180.0
# 3   2019       135.0
# 4   2020       140.0
# 5   2021       145.0
# 6   2022       160.0
# 7   2023       155.0
# 8   2024       170.0

# %%
x1 = df['years']
y1 = df['sell_of_mi']
plt.title('Sell of MI',{'color':'red','size':15})
plt.scatter(x1,y1,color='deeppink',marker='^',edgecolors = 'g')

# %%
plt.boxplot(x, showcaps = True,meanline=False,showfliers = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x271f3a186d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x271f3a19b10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x271f3a0fdd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x271f3a1ac90>],
#  'fliers': [],
#  'means': []}

# %%
plt.violinplot(x, vert= False, showmeans = True,showmedians = True)
# it use for distribution
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x271f3a74dd0>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x271f3a75410>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x271f3a75f50>,
#  'cmins': <matplotlib.collections.LineCollection at 0x271f3a76ed0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x271f3a80050>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x271f38d09d0>}

# %%
plt.hist(y1, color='green')
# sns.countplot(y1)
plt.title('sell of mi', color='red',fontsize=20)
# Out:
# Text(0.5, 1.0, 'sell of mi')

# %%
# date 27/05/2024

df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# x= df["total_bill"]
# y = df["tip"]
sns.scatterplot(x = 'total_bill', y = 'tip', 
                
data=df,
size ='size',

hue='time'
               
    )
plt.xlabel("Total bill Generatetd", color='green')
plt.ylabel("Tips to the service in USD $",color='green')
plt.title("New York",color='Blue')
# Out:
# Text(0.5, 1.0, 'New York')

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(x="total_bill", y ="size", data=df, hue='sex', style ="smoker",markers =True)
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %%
sns.barplot(x="size",y="total_bill", data=df ,palette = 'Accent' )
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11640\285302292.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="size",y="total_bill", data=df ,palette = 'Accent' )
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
# use for data distribution

sns.histplot(x='size' ,data=df, bins=5,kde= True,  color='deeppink')
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
sns.countplot( x ="size", data=df)
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(x= "size",data=df,fill = True, hue='sex', linewidth=2.0)

# %%
sns.kdeplot(x= "size",data=df,fill = True, hue='sex', linewidth=2.0)
# Out:
# <Axes: xlabel='size', ylabel='Density'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x ='day',y = 'tip', data=df)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
x=df['total_bill']
y =df['tip']

# %%
data = {
   "bill" =['total_bill"],
}
# Out:
#   Cell In[65], line 2
#     "bil"=df['total_bill'],
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
df1= pd.DataFrame(data)
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df1= pd.DataFrame(data)
#
# NameError: name 'data' is not defined

# %%
sns.heatmap(df1.corr(), linecolor="blue",linewidths =5,) #cmp='tab20',center=1,annot=True,

# %% [markdown]
# # pairplot

# %%
sns.pairplot(data=df, hue='sex')

# %%
sns.jointplot(x='total_bill', y= 'tip',data =df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 sns.jointplot(x='total_bill', y= 'bill',data =df)
#
# File C:\Python311\Lib\site-packages\seaborn\axisgrid.py:2243, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2240     dropna = True
#    2242 # Initialize the JointGrid object
# -> 2243 grid = JointGrid(
#    2244     data=data, x=x, y=y, hue=hue,
#    2245     palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#    2246     dropna=dropna, height=height, ratio=ratio, space=space,
#    2247     xlim=xlim, ylim=ylim, marginal_ticks=marginal_ticks,
#    2248 )
#    2250 if grid.hue is not None:
#    2251     marginal_kws.setdefault("legend", False)
#
# ...
